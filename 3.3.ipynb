# %%
a1 = {"hello":"world"}
a2 = {"sparsh":"handsome"}
a1.update(a2)
print(a1.keys())
for i in a1.items():
    print(i)
# Out:
# dict_keys(['hello', 'sparsh'])
# ('hello', 'world')
# ('sparsh', 'handsome')

# %%
a= [1,2,3,4]
print(a[1])
# Out:
# 2
